# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('../stat_analysis/data/ch4_scores400.csv')
scores = np.array(df['score'])
scores[:10]
# Out:
# array([76, 55, 80, 80, 74, 61, 81, 76, 23, 80])

# %%
np.random.choice([1,2,3], 3) #복원추출
# Out:
# array([2, 1, 3])

# %%
np.random.choice([1,2,3], 3, replace = False) #비복원추출
# Out:
# array([1, 2, 3])

# %%
np.random.seed(0)
sample = np.random.choice(scores, 20)
sample.mean()
# Out:
# 70.400

# %%
scores.mean()
# Out:
# 69.530

# %%
for i in range(5):
    sample = np.random.choice(scores, 20)
    print(f'{i+1}번째 무작위 추출로 얻은 표본평균', sample.mean())
# Out:
# 1번째 무작위 추출로 얻은 표본평균 72.45
# 2번째 무작위 추출로 얻은 표본평균 63.7
# 3번째 무작위 추출로 얻은 표본평균 66.05
# 4번째 무작위 추출로 얻은 표본평균 71.7
# 5번째 무작위 추출로 얻은 표본평균 74.15

# %%
dice = [1, 2, 3, 4, 5, 6]
prob = [1/21, 2/21, 3/21, 4/21, 5/21, 6/21]
np.random.choice(dice, p=prob) #p = prob는 확률을 prob로 지정
# Out:
# np.int64(6)

# %%
num_trial = 100
sample = np.random.choice(dice, num_trial, p = prob)
sample
# Out:
# array([4, 5, 5, 6, 6, 3, 5, 6, 5, 6, 6, 2, 3, 1, 6, 5, 6, 3, 4, 5, 3, 4,
#        3, 5, 5, 4, 4, 6, 4, 6, 5, 6, 5, 4, 6, 2, 6, 4, 5, 3, 4, 6, 5, 5,
#        5, 3, 4, 5, 4, 4, 6, 4, 4, 6, 6, 2, 2, 4, 5, 1, 6, 4, 3, 2, 2, 6,
#        3, 5, 4, 2, 4, 4, 6, 6, 1, 5, 3, 6, 6, 4, 2, 1, 6, 4, 4, 2, 4, 1,
#        3, 6, 6, 6, 4, 5, 4, 3, 3, 4, 6, 6])

# %%
freq, _ = np.histogram(sample, bins = 6, range = (1, 7))
pd.DataFrame({'frequency':freq, 'relative frequency':freq / num_trial}, index = pd.Index(np.arange(1, 7), name = 'dice'))
# Out:
#       frequency  relative frequency
# dice
# 1             5                0.05
# 2             9                0.09
# 3            13                0.13
# 4            26                0.26
# 5            19                0.19
# 6            28                0.28

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1, 7), density=True, rwidth=0.8)
#실제 확률분포를 가로선으로 표시
ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
#눈금표시
ax.set_xticks(np.linspace(1.5, 6.5, 6))
#눈의 값 표시
ax.set_xticklabels(np.arange(1, 7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()

# %%
num_trial = 10000
sample = np.random.choice(dice, num_trial, p = prob)

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample, bins=6, range=(1, 7), density=True, rwidth=0.8)
#실제 확률분포를 가로선으로 표시
ax.hlines(prob, np.arange(1, 7), np.arange(2, 8), colors='gray')
#눈금표시
ax.set_xticks(np.linspace(1.5, 6.5, 6))
#눈의 값 표시
ax.set_xticklabels(np.arange(1, 7))
ax.set_xlabel('dice')
ax.set_ylabel('relative frequency')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(scores, bins = 100, range = (0, 100), density = True) 
#확률분포 표시
ax.set_xlim(20, 100)
ax.set_ylim(0, 0.042)
#나타낼 축의 범위 설정
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
sample = np.random.choice(scores, 10000)
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(scores, bins = 100, range = (0, 100), density = True) 
#확률분포 표시
ax.set_xlim(20, 100)
ax.set_ylim(0, 0.042)
#나타낼 축의 범위 설정
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()

# %%
sample_means = [np.random.choice(scores, 20).mean()
                for _ in range(10000)]
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.hist(sample_means, bins=100, range=(0, 100), density = True)
ax.vlines(np.mean(scores), 0, 1, 'gray')
ax.set_xlim(50, 90)
ax.set_ylim(0, 0.13)
ax.set_xlabel('score')
ax.set_ylabel('relative frequency')
plt.show()
